# %% [markdown]
# # Team 8 — complete LSE workflow
#
# This is the default project entry point. It contains no pricing or calibration implementation: it calls the repository's Python modules in order. The run starts only if an `LSE_API_KEY` is already configured on this computer and the user confirms. If the key is missing or the user declines, no download or file modification occurs. Raw LSE rows remain in the Git-ignored `Data/lse_local/` directory.

# %%
from main import run_project

run_project(confirm=True)
